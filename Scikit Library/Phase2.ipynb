# %% [markdown]
# # Linear Regression:

# %%
from sklearn.linear_model import LinearRegression 

x = [[1],[2],[3],[4],[5]]
y = [40,50,65,75,90]

model = LinearRegression()

model.fit(x,y)

hours = float(input("Enter Number Of Hours You Studied:"))

predicted_marks = model.predict([[hours]])

print(f"Based On The Amount Of Hours You Studied {hours} You May Score Around {predicted_marks}")
# Out:
# Enter Number Of Hours You Studied: 4.5
# Based On The Amount Of Hours You Studied 4.5 You May Score Around [82.75]

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression 

x = [[1],[2],[3],[4],[5]]
y = [0,0,1,1,1]

model = LogisticRegression()

model.fit(x,y)

hours = float(input("Enter Number Of Hours You Studied:"))

result = model.predict([[hours]]) [0] 

if result == 1: 
    print(f"Based On Studied Hours {hours} You Are Likely To Pass")
else:
    print(f"Bases On Studied Hours {hours} You Are Likely To Fail")
# Out:
# Enter Number Of Hours You Studied: 2.25
# Bases On Studied Hours 2.25 You Are Likely To Fail

# %% [markdown]
# # K Neighbors Classifier:

# %%
from sklearn.neighbors import KNeighborsClassifier

x = [
    [180,7],
    [200,7.5],
    [250,8],
    [300,8.5],
    [330,9],
    [360,9.5]
]

# 0 = Apple and 1 = Orange

y = [0,0,0,1,1,1]

model = KNeighborsClassifier(n_neighbors = 3)

model.fit(x,y) 

weight = float(input("Enter The Weight In Grams:"))
size = float(input("Enter The Size In CM:"))

result = model.predict([[weight,size]]) [0]

if result == 0:
    print("The Fruit Is Apple")
else:
    print("The Fruit Is Orange")
# Out:
# Enter The Weight In Grams: 200
# Enter The Size In CM: 9
# The Fruit Is Apple

# %% [markdown]
# # Decision Tree:

# %%
from sklearn.tree import DecisionTreeClassifier 

x = [
    [7,2], # Apple
    [8,3], # Apple
    [9,8], # Orange
    [10,9] # Orange     
]

y = [0,0,1,1] # 0 = Apple, 1 = Orange 

model = DecisionTreeClassifier()

model.fit(x,y) 

size = float(input("Enter The Fruit Size: "))
shade = float(input("Enter The Color Shade (1-10): "))

result = model.predict([[size,shade]]) [0]

if result == 0:
    print("This Is Likely An Apple")
else:
    print("This Is Likely An Orange")
# Out:
# Enter The Fruit Size:  4
# Enter The Color Shade (1-10):  5
# This Is Likely An Apple

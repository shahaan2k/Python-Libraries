# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [10,20,15,25]

plt.plot(x,y)
plt.show()

# %%
x = ['Mon', 'Tues', 'Wed', 'Thu', 'Fri']
y = [10,15,7,20,12] 

plt.plot(x,y) 
plt.title("Fabrics Sales This Week")
plt.xlabel("Days Of Week:")
plt.ylabel("No Of Sales:") 

plt.show()
